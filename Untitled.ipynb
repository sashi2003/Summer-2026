# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv('layoffs_events.csv')
df2 = pd.read_csv('news_sentiment.csv')
df3 = pd.read_csv('global_labor_indicators.csv')
df4 = pd.read_csv('us_labor_indicators.csv')

for name, df in [('layoffs_events', df1), ('news_sentiment', df2), 
                  ('us_labor', df3), ('global_labor', df4)]:
    print(f"\n{name}:")
    print(f"Shape: {df.shape}")
    print(f"Columns: {df.columns.tolist()}")
# Out:
# layoffs_events:
# Shape: (2470, 11)
# Columns: ['company', 'location', 'layoff_count', 'date', 'pct_workforce', 'industry', 'source_url', 'stage', 'raised_mm', 'country', 'is_ai_company']
#
# news_sentiment:
# Shape: (306, 10)
# Columns: ['date', 'title', 'source', 'sentiment', 'is_layoff_news', 'is_hiring_news', 'description', 'url', 'published_at', 'sentiment_cat']
#
# us_labor:
# Shape: (114, 6)
# Columns: ['year', 'country_code', 'country_name', 'unemployment_rate_pct', 'youth_unemployment_pct', 'employment_to_pop_pct']
#
# global_labor:
# Shape: (392, 10)
# Columns: ['date', 'unemployment_rate', 'jolts_job_openings_k', 'initial_jobless_claims_k', 'information_sector_emp_k', 'computer_math_emp_k', 'financial_emp_k', 'openings_per_unemployed', 'tech_emp_yoy_pct', 'claims_4w_avg']
